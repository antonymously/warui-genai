# %%
import os
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import requests

# %%
RENSHUU_API_KEY = os.getenv('RENSHUU_API_KEY')

# %%
headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/profile", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "id": "745516",
#     "real_name": "yaaaam",
#     "adventure_level": "345",
#     "user_length": "1 year ago",
#     "kao": "https://www.renshuu.org/img/adventure/f/edi7c56_100_20240408.png",
#     "studied": {
#         "today_all": 58,
#         "today_grammar": 12,
#         "today_vocab": 46,
#         "today_kanji": 0,
#         "today_sent": 0,
#         "today_aconj": 0,
#         "today_conj": 0,
#         "total": 2224,
#         "total_vocab": 974,
#         "total_kanji": 286,
#         "total_grammar": 193,
#         "total_sent": 771
#     },
#     "level_progress_percs": {
#         "vocab": {
#             "n1": 0,
#             "n2": 1,
#             "n3": 3,
#             "n4": 100,
#             "n5": 100
#         },
#         "kanji": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 11,
#             "n4": 100,
#             "n5": 100
#         },
#         "grammar": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 4,
#             "n4": 92,
#             "n5": 100
#         },
#         "sent": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 0,
#             "n4": 100,
#             "n5": 100
#         }
#     },
#     "streaks": {
#         "vocab": {
#             "correct_in_a_row": "26",
#             "correct_in_a_row_alltime": "261",
#             "days_studied_in_a_row": "2",
#             "days_studied_in_a_row_alltime": "6"
#         },
#         "kanji": {
#             "correct_in_a_row": "34",
#             "correct_in_a_row_alltime": "148",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "5"
#         },
#         "grammar": {
#             "correct_in_a_row": "23",
#             "correct_in_a_row_alltime": "225",
#             "days_studied_in_a_row": "4",
#             "days_studied_in_a_row_alltime": "9"
#         },
#         "sent": {
#             "correct_in_a_row": "29",
#             "correct_in_a_row_alltime": "257",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "7"
#         },
#         "conj": {
#             "correct_in_a_row": "0",
#             "correct_in_a_row_alltime": "0",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "0"
#         },
#         "aconj": {
#             "correct_in_a_row": "0",
#             "correct_in_a_row_alltime": "0",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "0"
#         }
#     },
#     "api_usage": {
#         "calls_today": 2,
#         "daily_allowance": 2000
#     }
# }

# %%
# lists, I don't use this in renshuu

headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/lists", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "termtype_groups": [
#         {
#             "termtype": "sent",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031884",
#                             "termtype": "sent",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "grammar",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031885",
#                             "termtype": "grammar",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "kanji",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031883",
#                             "termtype": "kanji",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "vocab",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031882",
#                             "termtype": "vocab",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         }
#     ],
#     "api_usage": {
#         "calls_today": 3,
#         "daily_allowance": 2000
#     }
# }

# %%
# schedules - I use this more in renshuu
# lists, I don't use this in renshuu
headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/schedule", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "schedules": [
#         {
#             "id": "4419328",
#             "name": "Pre-Intermediate Words (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 152,
#                 "new": 20
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "30"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "20"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "21"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "13"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "18"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "8"
#                 }
#             ],
#             "terms": {
#                 "total_count": 579,
#                 "studied_count": 333,
#                 "unstudied_count": 246,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3853757",
#             "name": "Words for Beginner Japanese",
#             "is_frozen": 0,
#             "today": {
#                 "review": 684,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "10"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "3"
#                 }
#             ],
#             "terms": {
#                 "total_count": 698,
#                 "studied_count": 698,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3856647",
#             "name": "Beginner Kanji (N5)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 67,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "1"
#                 }
#             ],
#             "terms": {
#                 "total_count": 80,
#                 "studied_count": 80,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "5070559",
#             "name": "Intermediate Kanji (N3)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 3,
#                 "new": 20
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "12",
#                     "terms_to_review": "20"
#                 },
#                 {
#                     "days_in_future": "13",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 376,
#                 "studied_count": 40,
#                 "unstudied_count": 336,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3932501",
#             "name": "Pre-Intermediate Kanji (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 96,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 166,
#                 "studied_count": 166,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3853758",
#             "name": "Beginner Japanese/N5",
#             "is_frozen": 0,
#             "today": {
#                 "review": 13,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "22",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "24",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "27",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "29",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "33",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 64,
#                 "studied_count": 64,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "4295149",
#             "name": "Pre-Intermediate Grammar (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 47,
#                 "new": 9
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "12",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "13",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 141,
#                 "studied_count": 132,
#                 "unstudied_count": 9,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3856646",
#             "name": "Beginner Sentences (N5)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 566,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "14"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "11"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "18"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "10"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 689,
#                 "studied_count": 689,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "4536869",
#             "name": "Pre-Intermediate Sentences (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 416,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "14"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "22"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "11"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "10"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 554,
#                 "studied_count": 554,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         }
#     ],
#     "api_usage": {
#         "calls_today": 4,
#         "daily_allowance": 2000
#     }
# }

# %%
# schedule id for N4 grammar: 4295149
# list the terms in this schedule
# this is good! it includes the mastery

headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/schedule/4295149/list", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "schedules": [
#         {
#             "id": "4295149",
#             "name": "Pre-Intermediate Grammar (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 47,
#                 "new": 9
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "12",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "13",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 141,
#                 "studied_count": 132,
#                 "unstudied_count": 9,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         }
#     ],
#     "contents": {
#         "group": "all",
#         "pg": 1,
#         "total_pg": 3,
#         "result_count": 141,
#         "per_pg": 50,
#         "terms": [
#             {
#                 "id": "1",
#                 "title_english": "",
#                 "title_japanese": "\u304b\u305f",
#                 "user_data": {
#                     "correct_count": 15,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 15,
#                             "missed_count": 2,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/06/24",
#                             "next_quiz": "2024/07/01"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "How to [A]; Way/style of [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/1"
#             },
#             {
#                 "id": "2",
#                 "title_english": "",
#                 "title_japanese": "\u3084\u3059\u3044",
#                 "user_data": {
#                     "correct_count": 18,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 18,
#                             "missed_count": 2,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/03",
#                             "next_quiz": "2024/07/07"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is easy to do"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/2"
#             },
#             {
#                 "id": "3",
#                 "title_english": "",
#                 "title_japanese": "\u306b\u304f\u3044",
#                 "user_data": {
#                     "correct_count": 21,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 21,
#                             "missed_count": 1,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/20",
#                             "next_quiz": "2024/07/21"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is hard/difficult to do"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/14"
#             },
#             {
#                 "id": "9",
#                 "title_english": "",
#                 "title_japanese": "\u304a\u308f\u308b",
#                 "user_data": {
#                     "correct_count": 21,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "88",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 21,
#                             "missed_count": 0,
#                             "mastery_perc": 88,
#                             "last_quizzed": "2024/06/08",
#                             "next_quiz": "2024/10/06"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "To finish [A]; [A] ends"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/10"
#             },
#             {
#                 "id": "10",
#                 "title_english": "",
#                 "title_japanese": "\u3088\u308a",
#                 "user_data": {
#                     "correct_count": 15,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "63",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 15,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/08/19"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is [C]-er than [B]; [A] is more [C] than [B] (comparison)."
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/11"
#             },
#             {
#                 "id": "11",
#                 "title_english": "",
#                 "title_japanese": "\u3088\u308a",
#                 "user_data": {
#                     "correct_count": 9,
#                     "missed_count": 4,
#                     "mastery_avg_perc": "0",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 9,
#                             "missed_count": 4,
#                             "mastery_perc": 0,
#                             "last_quizzed": "2024/07/11",
#                             "next_quiz": "2024/07/12"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is not as [C] as [B]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/11"
#             },
#             {
#                 "id": "16",
#                 "title_english": "",
#                 "title_japanese": "\u3066\u3082\u3044\u3044",
#                 "user_data": {
#                     "correct_count": 11,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 11,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/08/01"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "It is alright to [A]; the subject may [A]; it's alright if [A] (condition)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/18"
#             },
#             {
#                 "id": "19",
#                 "title_english": "",
#                 "title_japanese": "\u3057\u307e\u3046",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 2,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/06/24",
#                             "next_quiz": "2024/06/25"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "To finish/complete [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/21"
#             },
#             {
#                 "id": "20",
#                 "title_english": "",
#                 "title_japanese": "\u3057\u307e\u3046",
#                 "user_data": {
#                     "correct_count": 19,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 19,
#                             "missed_count": 2,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/08",
#                             "next_quiz": "2024/07/09"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] occurs (shows embarrassment / regret / disappointment over the action [A])"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/21"
#             },
#             {
#                 "id": "21",
#                 "title_english": "",
#                 "title_japanese": "\u3066\u304a\u304f",
#                 "user_data": {
#                     "correct_count": 16,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "0",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 16,
#                             "missed_count": 2,
#                             "mastery_perc": 0,
#                             "last_quizzed": "2024/07/13",
#                             "next_quiz": "2024/07/14"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "To do [A] in advance; do [A] as preparation for something else"
#                 },
#                 "meaning_long": {
#                     "eng": "(used with transitive verbs)"
#                 },
#                 "url": "https://www.resnhuu.org/grammar/22"
#             },
#             {
#                 "id": "24",
#                 "title_english": "",
#                 "title_japanese": "\u307e\u307e",
#                 "user_data": {
#                     "correct_count": 25,
#                     "missed_count": 4,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 25,
#                             "missed_count": 4,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/17",
#                             "next_quiz": "2024/07/18"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "The situation [A] remains unchanged"
#                 },
#                 "meaning_long": {
#                     "eng": "Unlike \u307e\u3060, carries the meaning that the situation [A] was left that way by someone. Often used in a (Leaving [A] as is, I do something else.)"
#                 },
#                 "url": "https://www.resnhuu.org/grammar/25"
#             },
#             {
#                 "id": "25",
#                 "title_english": "",
#                 "title_japanese": "\u306a\u3051\u308c\u3070\u306a\u3089\u306a\u3044",
#                 "user_data": {
#                     "correct_count": 20,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 20,
#                             "missed_count": 1,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/07/22",
#                             "next_quiz": "2024/08/06"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Must do [A]; have to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/26"
#             },
#             {
#                 "id": "26",
#                 "title_english": "",
#                 "title_japanese": "\u306a\u304f\u3066\u306f\u3044\u3051\u306a\u3044/\u306a\u3089\u306a\u3044",
#                 "user_data": {
#                     "correct_count": 8,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 8,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/10",
#                             "next_quiz": "2024/07/14"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Must do [A]; have to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/27"
#             },
#             {
#                 "id": "27",
#                 "title_english": "",
#                 "title_japanese": "\u306a\u304f\u3066\u3082\u3044\u3044",
#                 "user_data": {
#                     "correct_count": 33,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "63",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 33,
#                             "missed_count": 2,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/08/18"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Don't have to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/28"
#             },
#             {
#                 "id": "28",
#                 "title_english": "",
#                 "title_japanese": "\u3066\u3082\u304b\u307e\u308f\u306a\u3044",
#                 "user_data": {
#                     "correct_count": 21,
#                     "missed_count": 3,
#                     "mastery_avg_perc": "63",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 21,
#                             "missed_count": 3,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/08",
#                             "next_quiz": "2024/08/02"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Doesn't matter if [A] (isn't done); don't mind if [A] (isn't done)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/19"
#             },
#             {
#                 "id": "30",
#                 "title_english": "",
#                 "title_japanese": "\u306a\u3044\u65b9\u304c\u3044\u3044",
#                 "user_data": {
#                     "correct_count": 16,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "63",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 16,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/03",
#                             "next_quiz": "2024/07/28"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "It would be better to not [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/31"
#             },
#             {
#                 "id": "31",
#                 "title_english": "",
#                 "title_japanese": "\u305f\u65b9\u304c\u3044\u3044",
#                 "user_data": {
#                     "correct_count": 28,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "100",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 28,
#                             "missed_count": 0,
#                             "mastery_perc": 100,
#                             "last_quizzed": "2024/07/13",
#                             "next_quiz": "2025/03/10"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "It would be better to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/32"
#             },
#             {
#                 "id": "32",
#                 "title_english": "",
#                 "title_japanese": "\u3053\u3068\u304c\u3042\u308b",
#                 "user_data": {
#                     "correct_count": 8,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 8,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/06/22",
#                             "next_quiz": "2024/06/26"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "There are times when [A] (occurs/exists)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/33"
#             },
#             {
#                 "id": "33",
#                 "title_english": "",
#                 "title_japanese": "\u3093\u3067\u3059",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/07/17",
#                             "next_quiz": "2024/08/01"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "The reason/explanation is [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/34"
#             },
#             {
#                 "id": "37",
#                 "title_english": "",
#                 "title_japanese": "\u3093\u3067\u3059\u304c/\u3093\u3060\u304c",
#                 "user_data": {
#                     "correct_count": 18,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "63",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 18,
#                             "missed_count": 2,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/08/18"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Introduces a request, invitation, or asking for permission"
#                 },
#                 "meaning_long": {
#                     "eng": "The actual request may not be stated, and is implied by stating some problem or issue (with the request being to fix the problem)."
#                 },
#                 "url": "https://www.resnhuu.org/grammar/35"
#             },
#             {
#                 "id": "41",
#                 "title_english": "",
#                 "title_japanese": "\u305d\u3046",
#                 "user_data": {
#                     "correct_count": 20,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 20,
#                             "missed_count": 1,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/07/27",
#                             "next_quiz": "2024/08/11"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is spoken by/heard from someone/something else"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/36"
#             },
#             {
#                 "id": "42",
#                 "title_english": "",
#                 "title_japanese": "\u304b",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 2,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/08/01"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is a question within the sentence"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/37"
#             },
#             {
#                 "id": "43",
#                 "title_english": "",
#                 "title_japanese": "\u304b\u3069\u3046\u304b",
#                 "user_data": {
#                     "correct_count": 15,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 15,
#                             "missed_count": 2,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/22",
#                             "next_quiz": "2024/07/29"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Whether or not [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/38"
#             },
#             {
#                 "id": "44",
#                 "title_english": "",
#                 "title_japanese": "\u3068\u3053\u308d",
#                 "user_data": {
#                     "correct_count": 27,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "75",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 27,
#                             "missed_count": 1,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/09/12"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "About to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/40"
#             },
#             {
#                 "id": "45",
#                 "title_english": "",
#                 "title_japanese": "\u3068\u3053\u308d",
#                 "user_data": {
#                     "correct_count": 18,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "75",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 18,
#                             "missed_count": 0,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/07/18",
#                             "next_quiz": "2024/09/06"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Be now [A]...ing (be in the middle of doing [A])"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/40"
#             },
#             {
#                 "id": "46",
#                 "title_english": "",
#                 "title_japanese": "\u3068\u3053\u308d",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 1,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/22",
#                             "next_quiz": "2024/07/29"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Just finished [A]; Have been [A]...ing"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/40"
#             },
#             {
#                 "id": "47",
#                 "title_english": "",
#                 "title_japanese": "\u3059\u304e\u308b",
#                 "user_data": {
#                     "correct_count": 29,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "88",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 29,
#                             "missed_count": 1,
#                             "mastery_perc": 88,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/11/22"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is done too much"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/41"
#             },
#             {
#                 "id": "48",
#                 "title_english": "",
#                 "title_japanese": "\u3059\u304e\u308b",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/06/26",
#                             "next_quiz": "2024/07/11"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Too much [A]; [A] is excessive"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/41"
#             },
#             {
#                 "id": "52",
#                 "title_english": "",
#                 "title_japanese": "\u306b\u884c\u304f",
#                 "user_data": {
#                     "correct_count": 6,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 6,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/10",
#                             "next_quiz": "2024/07/11"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Go (somewhere) in order to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/44"
#             },
#             {
#                 "id": "53",
#                 "title_english": "",
#                 "title_japanese": "\u306b\u6765\u308b",
#                 "user_data": {
#                     "correct_count": 5,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 5,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/11",
#                             "next_quiz": "2024/07/12"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Come (here) in order to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/45"
#             },
#             {
#                 "id": "54",
#                 "title_english": "",
#                 "title_japanese": "\u306b\u5e30\u308b",
#                 "user_data": {
#                     "correct_count": 11,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 11,
#                             "missed_count": 1,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/22",
#                             "next_quiz": "2024/07/23"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Return (home) in order to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/46"
#             },
#             {
#                 "id": "57",
#                 "title_english": "",
#                 "title_japanese": "\u3070\u304b\u308a",
#                 "user_data": {
#                     "correct_count": 21,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "88",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 21,
#                             "missed_count": 0,
#                             "mastery_perc": 88,
#                             "last_quizzed": "2024/06/12",
#                             "next_quiz": "2024/10/10"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Do only [A]; do nothing but [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/49"
#             },
#             {
#                 "id": "59",
#                 "title_english": "Passive",
#                 "title_japanese": "\u53d7\u8eab",
#                 "user_data": {
#                     "correct_count": 23,
#                     "missed_count": 17,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 23,
#                             "missed_count": 17,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/18",
#                             "next_quiz": "2024/07/19"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Be [A]-ed (Passive tense), when the action is directed at the subject. "
#                 },
#                 "meaning_long": {
#                     "eng": "When included, the agent of the action is marked with \u306b"
#                 },
#                 "url": "https://www.resnhuu.org/grammar/51"
#             },
#             {
#                 "id": "62",
#                 "title_english": "Passive",
#                 "title_japanese": "\u53d7\u8eab",
#                 "user_data": {
#                     "correct_count": 20,
#                     "missed_count": 7,
#                     "mastery_avg_perc": "0",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 20,
#                             "missed_count": 7,
#                             "mastery_perc": 0,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/07/26"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] is done, [A] happens"
#                 },
#                 "meaning_long": {
#                     "eng": "The action is not usually directed at the subject, but has a negative/undesirable connotation."
#                 },
#                 "url": "https://www.resnhuu.org/grammar/51"
#             },
#             {
#                 "id": "63",
#                 "title_english": "Causative",
#                 "title_japanese": "\u3055\u305b\u308b (\u4f7f\u5f79)",
#                 "user_data": {
#                     "correct_count": 11,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 11,
#                             "missed_count": 1,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/27",
#                             "next_quiz": "2024/07/28"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Make (somebody) [A], this is coercive or forced onto the object of the sentence."
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/52"
#             },
#             {
#                 "id": "64",
#                 "title_english": "Causative",
#                 "title_japanese": "\u3055\u305b\u308b (\u4f7f\u5f79)",
#                 "user_data": {
#                     "correct_count": 32,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "88",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 32,
#                             "missed_count": 1,
#                             "mastery_perc": 88,
#                             "last_quizzed": "2024/07/20",
#                             "next_quiz": "2024/11/17"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Allow (somebody) to [A], this is permission from the subject to the object."
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/52"
#             },
#             {
#                 "id": "65",
#                 "title_english": "Causative",
#                 "title_japanese": "\u3055\u305b\u308b (\u4f7f\u5f79)",
#                 "user_data": {
#                     "correct_count": 37,
#                     "missed_count": 5,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 37,
#                             "missed_count": 5,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/07/10",
#                             "next_quiz": "2024/07/25"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Make (somebody) [A], because of the subject; the object is caused to [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/52"
#             },
#             {
#                 "id": "66",
#                 "title_english": "Causative Passive",
#                 "title_japanese": "\u3055\u305b\u3089\u308c\u308b (\u4f7f\u5f79\u53d7\u8eab)",
#                 "user_data": {
#                     "correct_count": 28,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "100",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 28,
#                             "missed_count": 0,
#                             "mastery_perc": 100,
#                             "last_quizzed": "2024/07/13",
#                             "next_quiz": "2025/03/10"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Be made to do [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/53"
#             },
#             {
#                 "id": "67",
#                 "title_english": "Potential",
#                 "title_japanese": "\u3089\u308c\u308b",
#                 "user_data": {
#                     "correct_count": 38,
#                     "missed_count": 5,
#                     "mastery_avg_perc": "88",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 38,
#                             "missed_count": 5,
#                             "mastery_perc": 88,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/11/21"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Can [A]; be able to [A] (ability of the subject)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/55"
#             },
#             {
#                 "id": "68",
#                 "title_english": "Potential",
#                 "title_japanese": "\u3089\u308c\u308b",
#                 "user_data": {
#                     "correct_count": 39,
#                     "missed_count": 6,
#                     "mastery_avg_perc": "38",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 39,
#                             "missed_count": 6,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/07/11",
#                             "next_quiz": "2024/07/18"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Can [A]; be possible to [A]; (possibility of the subject to do [A])"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/55"
#             },
#             {
#                 "id": "69",
#                 "title_english": "",
#                 "title_japanese": "\u3053\u3068\u304c\u51fa\u6765\u308b",
#                 "user_data": {
#                     "correct_count": 13,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "50",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/08/08"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Be able to [A]; can do [A]"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/56"
#             },
#             {
#                 "id": "70",
#                 "title_english": "",
#                 "title_japanese": "\u3053\u3068\u304c\u51fa\u6765\u308b",
#                 "user_data": {
#                     "correct_count": 11,
#                     "missed_count": 3,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 11,
#                             "missed_count": 3,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/22",
#                             "next_quiz": "2024/07/23"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Can [A]; be possible to [A] (possibility of the subject to do [A])"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/56"
#             },
#             {
#                 "id": "73",
#                 "title_english": "",
#                 "title_japanese": "\u304f\u308c\u308b",
#                 "user_data": {
#                     "correct_count": 41,
#                     "missed_count": 5,
#                     "mastery_avg_perc": "75",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 41,
#                             "missed_count": 5,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/07/27",
#                             "next_quiz": "2024/09/15"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] gives [C] to [B] ([B] is you, your friends, your family, etc.)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/59"
#             },
#             {
#                 "id": "74",
#                 "title_english": "",
#                 "title_japanese": "\u3042\u3052\u308b",
#                 "user_data": {
#                     "correct_count": 37,
#                     "missed_count": 5,
#                     "mastery_avg_perc": "75",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 37,
#                             "missed_count": 5,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/07/24",
#                             "next_quiz": "2024/09/12"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Give [B] to [A] ([A] is a third party, not yourself)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/60"
#             },
#             {
#                 "id": "75",
#                 "title_english": "",
#                 "title_japanese": "\u304f\u3060\u3055\u308b",
#                 "user_data": {
#                     "correct_count": 31,
#                     "missed_count": 9,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 31,
#                             "missed_count": 9,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/15",
#                             "next_quiz": "2024/07/16"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Give [B] to [A] ([A] is you, your friends, your family, etc.)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/61"
#             },
#             {
#                 "id": "76",
#                 "title_english": "",
#                 "title_japanese": "\u3055\u3057\u3042\u3052\u308b",
#                 "user_data": {
#                     "correct_count": 31,
#                     "missed_count": 3,
#                     "mastery_avg_perc": "100",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 31,
#                             "missed_count": 3,
#                             "mastery_perc": 100,
#                             "last_quizzed": "2024/06/13",
#                             "next_quiz": "2025/02/08"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Give [B] to [A] ([A] is a third party, not yourself)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/62"
#             },
#             {
#                 "id": "77",
#                 "title_english": "",
#                 "title_japanese": "\u3084\u308b",
#                 "user_data": {
#                     "correct_count": 25,
#                     "missed_count": 4,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 25,
#                             "missed_count": 4,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/07/26"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "Give [B] to [A] ([A] is an animal, plant, or someone below you in ranking)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/63"
#             },
#             {
#                 "id": "78",
#                 "title_english": "",
#                 "title_japanese": "\u3082\u3089\u3046",
#                 "user_data": {
#                     "correct_count": 21,
#                     "missed_count": 2,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 21,
#                             "missed_count": 2,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/06",
#                             "next_quiz": "2024/07/10"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] receives [C] from [B]: the giver is of the same/lower rank of the recipient."
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/64"
#             },
#             {
#                 "id": "79",
#                 "title_english": "",
#                 "title_japanese": "\u3044\u305f\u3060\u304f",
#                 "user_data": {
#                     "correct_count": 33,
#                     "missed_count": 3,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 33,
#                             "missed_count": 3,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/06/26",
#                             "next_quiz": "2024/06/27"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] receives [C] from [B]: the giver is of a higher rank than the recipient."
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/65"
#             },
#             {
#                 "id": "80",
#                 "title_english": "",
#                 "title_japanese": "\u3066\u304f\u308c\u308b",
#                 "user_data": {
#                     "correct_count": 48,
#                     "missed_count": 12,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Main": {
#                             "name": "Main",
#                             "correct_count": 48,
#                             "missed_count": 12,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/06/26",
#                             "next_quiz": "2024/06/27"
#                         }
#                     }
#                 },
#                 "meaning": {
#                     "eng": "[A] does [B] for [C] ([C] is you, your friends, your family, etc.)"
#                 },
#                 "meaning_long": {
#                     "eng": ""
#                 },
#                 "url": "https://www.resnhuu.org/grammar/66"
#             }
#         ]
#     },
#     "api_usage": {
#         "calls_today": 6,
#         "daily_allowance": 2000
#     }
# }
