# %%
import os
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import requests

# %%
RENSHUU_API_KEY = os.getenv('RENSHUU_API_KEY')

# %%
headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/profile", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "id": "745516",
#     "real_name": "yaaaam",
#     "adventure_level": "379",
#     "user_length": "1 year ago",
#     "kao": "https://www.renshuu.org/img/adventure/f/30sctqp_100_20240408.png",
#     "studied": {
#         "today_all": 85,
#         "today_grammar": 0,
#         "today_vocab": 46,
#         "today_kanji": 0,
#         "today_sent": 39,
#         "today_aconj": 0,
#         "today_conj": 0,
#         "total": 2280,
#         "total_vocab": 1009,
#         "total_kanji": 298,
#         "total_grammar": 202,
#         "total_sent": 771
#     },
#     "level_progress_percs": {
#         "vocab": {
#             "n1": 0,
#             "n2": 1,
#             "n3": 3,
#             "n4": 100,
#             "n5": 100
#         },
#         "kanji": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 14,
#             "n4": 100,
#             "n5": 100
#         },
#         "grammar": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 4,
#             "n4": 99,
#             "n5": 100
#         },
#         "sent": {
#             "n1": 0,
#             "n2": 0,
#             "n3": 0,
#             "n4": 100,
#             "n5": 100
#         }
#     },
#     "streaks": {
#         "vocab": {
#             "correct_in_a_row": "77",
#             "correct_in_a_row_alltime": "261",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "6"
#         },
#         "kanji": {
#             "correct_in_a_row": "15",
#             "correct_in_a_row_alltime": "148",
#             "days_studied_in_a_row": "1",
#             "days_studied_in_a_row_alltime": "5"
#         },
#         "grammar": {
#             "correct_in_a_row": "16",
#             "correct_in_a_row_alltime": "225",
#             "days_studied_in_a_row": "4",
#             "days_studied_in_a_row_alltime": "9"
#         },
#         "sent": {
#             "correct_in_a_row": "25",
#             "correct_in_a_row_alltime": "257",
#             "days_studied_in_a_row": "1",
#             "days_studied_in_a_row_alltime": "7"
#         },
#         "conj": {
#             "correct_in_a_row": "0",
#             "correct_in_a_row_alltime": "0",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "0"
#         },
#         "aconj": {
#             "correct_in_a_row": "0",
#             "correct_in_a_row_alltime": "0",
#             "days_studied_in_a_row": "0",
#             "days_studied_in_a_row_alltime": "0"
#         }
#     },
#     "api_usage": {
#         "calls_today": 5,
#         "daily_allowance": 2000
#     }
# }

# %%
# lists, I don't use this in renshuu

headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/lists", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "termtype_groups": [
#         {
#             "termtype": "sent",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031884",
#                             "termtype": "sent",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "grammar",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031885",
#                             "termtype": "grammar",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "kanji",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031883",
#                             "termtype": "kanji",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         },
#         {
#             "termtype": "vocab",
#             "list_count": 1,
#             "groups": [
#                 {
#                     "list_count": 1,
#                     "lists": [
#                         {
#                             "list_id": "5031882",
#                             "termtype": "vocab",
#                             "title": "Studypad",
#                             "description": "",
#                             "num_terms": "0",
#                             "privacy": "private"
#                         }
#                     ],
#                     "group_title": "(not grouped)"
#                 }
#             ]
#         }
#     ],
#     "api_usage": {
#         "calls_today": 6,
#         "daily_allowance": 2000
#     }
# }

# %%
# schedules - I use this more in renshuu
# lists, I don't use this in renshuu
headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/schedule", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "schedules": [
#         {
#             "id": "4419328",
#             "name": "Pre-Intermediate Words (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 163,
#                 "new": 20
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "18"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "21"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "11"
#                 }
#             ],
#             "terms": {
#                 "total_count": 579,
#                 "studied_count": 363,
#                 "unstudied_count": 216,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3853757",
#             "name": "Words for Beginner Japanese",
#             "is_frozen": 0,
#             "today": {
#                 "review": 674,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "15"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "12"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 698,
#                 "studied_count": 698,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3856647",
#             "name": "Beginner Kanji (N5)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 58,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "6"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "5"
#                 }
#             ],
#             "terms": {
#                 "total_count": 80,
#                 "studied_count": 80,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "5070559",
#             "name": "Intermediate Kanji (N3)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 13,
#                 "new": 20
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "11",
#                     "terms_to_review": "14"
#                 },
#                 {
#                     "days_in_future": "13",
#                     "terms_to_review": "10"
#                 },
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 376,
#                 "studied_count": 52,
#                 "unstudied_count": 324,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3932501",
#             "name": "Pre-Intermediate Kanji (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 69,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 166,
#                 "studied_count": 166,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3853758",
#             "name": "Beginner Japanese/N5",
#             "is_frozen": 0,
#             "today": {
#                 "review": 20,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "16",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "26",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "30",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 64,
#                 "studied_count": 64,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "5657104",
#             "name": "Grammar: Genki I and Renshuu (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 62,
#                 "new": 27
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "4"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "10",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "11",
#                     "terms_to_review": "2"
#                 },
#                 {
#                     "days_in_future": "12",
#                     "terms_to_review": "1"
#                 },
#                 {
#                     "days_in_future": "14",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "0"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "0"
#                 }
#             ],
#             "terms": {
#                 "total_count": 190,
#                 "studied_count": 163,
#                 "unstudied_count": 27,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "3856646",
#             "name": "Beginner Sentences (N5)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 533,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "25"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "7"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "6"
#                 }
#             ],
#             "terms": {
#                 "total_count": 689,
#                 "studied_count": 689,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         },
#         {
#             "id": "4536869",
#             "name": "Pre-Intermediate Sentences (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 384,
#                 "new": 0
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "12"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "27"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "10"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "8"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "3"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "9"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "6"
#                 }
#             ],
#             "terms": {
#                 "total_count": 554,
#                 "studied_count": 554,
#                 "unstudied_count": 0,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         }
#     ],
#     "api_usage": {
#         "calls_today": 7,
#         "daily_allowance": 2000
#     }
# }

# %%
# schedule id for N4 grammar: 4419328
# list the terms in this schedule
# this is good! it includes the mastery

headers = {
    'Authorization': f'Bearer {RENSHUU_API_KEY}',
    'Content-Type': 'application/json'
}

response = requests.get(
    "https://api.renshuu.org/v1/schedule/4419328/list", 
    headers=headers
)
print(json.dumps(response.json(), indent = 4))
# Out:
# {
#     "schedules": [
#         {
#             "id": "4419328",
#             "name": "Pre-Intermediate Words (N4)",
#             "is_frozen": 0,
#             "today": {
#                 "review": 163,
#                 "new": 20
#             },
#             "upcoming": [
#                 {
#                     "days_in_future": "1",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "2",
#                     "terms_to_review": "17"
#                 },
#                 {
#                     "days_in_future": "3",
#                     "terms_to_review": "18"
#                 },
#                 {
#                     "days_in_future": "4",
#                     "terms_to_review": "19"
#                 },
#                 {
#                     "days_in_future": "5",
#                     "terms_to_review": "21"
#                 },
#                 {
#                     "days_in_future": "6",
#                     "terms_to_review": "5"
#                 },
#                 {
#                     "days_in_future": "7",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "8",
#                     "terms_to_review": "16"
#                 },
#                 {
#                     "days_in_future": "9",
#                     "terms_to_review": "11"
#                 }
#             ],
#             "terms": {
#                 "total_count": 579,
#                 "studied_count": 363,
#                 "unstudied_count": 216,
#                 "hidden_count": 0
#             },
#             "new_terms": {
#                 "today_count": 0,
#                 "rolling_week_count": 0
#             }
#         }
#     ],
#     "contents": {
#         "group": "all",
#         "pg": 1,
#         "total_pg": 12,
#         "result_count": 579,
#         "per_pg": 50,
#         "terms": [
#             {
#                 "kanji_full": "\u55da\u547c",
#                 "hiragana_full": "\u3042\u3042",
#                 "id": "1",
#                 "edict_ent": "1565440",
#                 "config": [
#                     "unique-furigana",
#                     "common-hiragana",
#                     "ent_primary",
#                     "ateji"
#                 ],
#                 "user_data": {
#                     "correct_count": 6,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 4,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/08/27",
#                             "next_quiz": "2024/09/08"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/10",
#                             "next_quiz": "2024/08/29"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         }
#                     }
#                 },
#                 "reibuns": "71",
#                 "pitch": [
#                     "\u2b67\u3042\u2b68\u3042"
#                 ],
#                 "typeofspeech": "(expression)",
#                 "def": [
#                     "ah!, oh!, alas!",
#                     "yes, indeed, that is correct",
#                     "aah, gah, argh (in exasperation)",
#                     "hey!, yo!",
#                     "uh huh, yeah yeah, right, gotcha"
#                 ]
#             },
#             {
#                 "kanji_full": "\u5acc",
#                 "hiragana_full": "\u3044\u3084",
#                 "id": "64",
#                 "edict_ent": "1587610",
#                 "config": [
#                     "common-hiragana",
#                     "ent_primary"
#                 ],
#                 "user_data": {
#                     "correct_count": 26,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "33",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 12,
#                             "missed_count": 0,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/08/17",
#                             "next_quiz": "2024/11/06"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 13,
#                             "missed_count": 1,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/09/01",
#                             "next_quiz": "2024/11/24"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2023/10/03",
#                             "next_quiz": "2024/09/03"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/02"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/02"
#                         }
#                     }
#                 },
#                 "reibuns": "205",
#                 "pitch": [
#                     "\u3044\u2b67\u3084\u2b68"
#                 ],
#                 "typeofspeech": "(Adjective/-\u306a)",
#                 "def": [
#                     "disliking, not wanting, unwilling (to do), reluctant",
#                     "unpleasant, disagreeable, nasty, horrible, disgusting, undesirable, unwelcome",
#                     "{int} no!, quit it!, stop!"
#                 ]
#             },
#             {
#                 "kanji_full": "\u5bb6\u5185",
#                 "hiragana_full": "\u304b\u306a\u3044",
#                 "id": "160",
#                 "edict_ent": "1192420",
#                 "config": [
#                     "ent_primary"
#                 ],
#                 "user_data": {
#                     "correct_count": 5,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "7",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/27",
#                             "next_quiz": "2024/08/26"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/18",
#                             "next_quiz": "2024/08/22"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/16",
#                             "next_quiz": "2024/08/21"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         }
#                     }
#                 },
#                 "reibuns": "9",
#                 "pitch": [
#                     "\u2b67\u304b\u2b68\u306a\u3044"
#                 ],
#                 "typeofspeech": "(noun)",
#                 "def": [
#                     "{hum} (my) wife",
#                     "inside the home, one's family"
#                 ]
#             },
#             {
#                 "kanji_full": "\u5fa1\u4e3b\u4eba",
#                 "hiragana_full": "\u3054\u3057\u3085\u3058\u3093",
#                 "id": "236",
#                 "edict_ent": "1270390",
#                 "config": [],
#                 "user_data": {
#                     "correct_count": 3,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "4",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/07/25",
#                             "next_quiz": "2024/09/05"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/08/11",
#                             "next_quiz": "2024/09/08"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/08/31",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         }
#                     }
#                 },
#                 "reibuns": "9",
#                 "pitch": [
#                     "\u3054\u2b67\u3057\u3085\u2b68\u3058\u3093"
#                 ],
#                 "typeofspeech": "(noun)",
#                 "def": [
#                     "{hon} your husband, her husband"
#                 ]
#             },
#             {
#                 "kanji_full": "\u7de0\u3081\u308b",
#                 "hiragana_full": "\u3057\u3081\u308b",
#                 "id": "288",
#                 "edict_ent": "1436570",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 6,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "15",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 3,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/08/27",
#                             "next_quiz": "2024/09/06"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 3,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/08/10",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         }
#                     }
#                 },
#                 "reibuns": "34",
#                 "pitch": [
#                     "\u3057\u2b67\u3081\u2b68\u308b"
#                 ],
#                 "typeofspeech": "(Ichidan verb (\u307e\u3059 = stem+\u307e\u3059)/transitive)",
#                 "def": [
#                     "to tie, to fasten, to tighten",
#                     "to wear (necktie, belt), to put on",
#                     "to total, to sum",
#                     "to be strict with",
#                     "to economize, to economise, to cut down on",
#                     "to salt, to marinate, to pickle, to make sushi adding a mixture of vinegar and salt",
#                     "to kill (fish, poultry, etc.)"
#                 ]
#             },
#             {
#                 "kanji_full": "\u4eba",
#                 "hiragana_full": "\u3058\u3093",
#                 "id": "303",
#                 "edict_ent": "1366410",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 4,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "6",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/18",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/24",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/25"
#                         }
#                     }
#                 },
#                 "reibuns": "24",
#                 "pitch": [
#                     "\u2b67\u3058\u2b68\u3093"
#                 ],
#                 "typeofspeech": "(suffix)",
#                 "def": [
#                     "-ian (e.g. Italian), -ite (e.g. Tokyoite) (indicates nationality, race, origin, etc.)",
#                     "-er (e.g. performer, etc.), person working with ... (indicates expertise (in a certain field))",
#                     "man, person, people (usu. in compound words)"
#                 ]
#             },
#             {
#                 "kanji_full": "\u904e\u304e",
#                 "hiragana_full": "\u3059\u304e",
#                 "id": "309",
#                 "edict_ent": "1195960",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 15,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "18",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/15",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/21"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/18",
#                             "next_quiz": "2024/08/23"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 3,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/20",
#                             "next_quiz": "2024/08/24"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 5,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/05/09",
#                             "next_quiz": "2024/08/23"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 3,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/05/04",
#                             "next_quiz": "2024/08/23"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/21"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/21"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/21"
#                         }
#                     }
#                 },
#                 "reibuns": "92",
#                 "pitch": [
#                     "\u3059\u2b67\u304e\u2b68"
#                 ],
#                 "typeofspeech": "(suffix)",
#                 "def": [
#                     "past, after",
#                     "too (much), over- (e.g. eating)"
#                 ]
#             },
#             {
#                 "kanji_full": "",
#                 "hiragana_full": "\u305d\u3046",
#                 "id": "335",
#                 "edict_ent": "1006610",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 5,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "13",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/07/27",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 3,
#                             "missed_count": 0,
#                             "mastery_perc": 38,
#                             "last_quizzed": "2024/08/27",
#                             "next_quiz": "2024/09/08"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         }
#                     }
#                 },
#                 "reibuns": "1000",
#                 "pitch": [
#                     "\u2b67\u305d\u2b68\u3046"
#                 ],
#                 "typeofspeech": "(adverb)",
#                 "def": [
#                     "appearing that, seeming that, looking like, having the appearance of (after -masu stem or adj. stem)"
#                 ]
#             },
#             {
#                 "kanji_full": "\u7136\u3046\u3057\u3066",
#                 "hiragana_full": "\u305d\u3046\u3057\u3066",
#                 "id": "337",
#                 "edict_ent": "1612860",
#                 "config": [
#                     "common-hiragana",
#                     "ent_single",
#                     "rK"
#                 ],
#                 "user_data": {
#                     "correct_count": 32,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "28",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 16,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/07/23",
#                             "next_quiz": "2024/10/02"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 15,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/08/17",
#                             "next_quiz": "2024/10/18"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 1,
#                             "missed_count": 1,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2023/10/12",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/18"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/18"
#                         }
#                     }
#                 },
#                 "reibuns": "6",
#                 "pitch": [
#                     "\u305d\u2b67\u3046\u3057\u3066"
#                 ],
#                 "typeofspeech": "(expression)",
#                 "def": [
#                     "and, like that"
#                 ]
#             },
#             {
#                 "kanji_full": "\u5339",
#                 "hiragana_full": "\u3072\u304d",
#                 "id": "525",
#                 "edict_ent": "1583370",
#                 "config": [
#                     "ent_primary"
#                 ],
#                 "user_data": {
#                     "correct_count": 33,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "43",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/08/31",
#                             "next_quiz": "2024/11/04"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 15,
#                             "missed_count": 0,
#                             "mastery_perc": 75,
#                             "last_quizzed": "2024/07/13",
#                             "next_quiz": "2024/10/20"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 5,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2023/12/01",
#                             "next_quiz": "2024/09/03"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         }
#                     }
#                 },
#                 "reibuns": "70",
#                 "pitch": [
#                     "\u3072\u2b67\u304d",
#                     "\u2b67\u3072\u2b68\u304d"
#                 ],
#                 "typeofspeech": "(suffix)",
#                 "def": [
#                     "counter for small animals",
#                     "counter for rolls of cloth (two han in size)",
#                     "{n} roll of cloth"
#                 ]
#             },
#             {
#                 "kanji_full": "\u9593",
#                 "hiragana_full": "\u3042\u3044\u3060",
#                 "id": "685",
#                 "edict_ent": "1215230",
#                 "config": [
#                     "ent_primary"
#                 ],
#                 "user_data": {
#                     "correct_count": 20,
#                     "missed_count": 1,
#                     "mastery_avg_perc": "20",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 6,
#                             "missed_count": 1,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/08/15",
#                             "next_quiz": "2024/09/30"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 7,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/08/31",
#                             "next_quiz": "2024/10/11"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 7,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/08/13",
#                             "next_quiz": "2024/09/23"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Writing": {
# ...
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/13",
#                             "next_quiz": "2024/09/04"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/27",
#                             "next_quiz": "2024/08/31"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         }
#                     }
#                 },
#                 "reibuns": "31",
#                 "pitch": [
#                     "\u3046\u2b67\u3064\u2b68\u308b"
#                 ],
#                 "typeofspeech": "(Godan verb - \u308b (\u307e\u3059 = stem+\u308a\u307e\u3059)/intransitive)",
#                 "def": [
#                     "to move (house), to transfer (department)",
#                     "to change the target of interest or concern",
#                     "to elapse (passage of time)",
#                     "to be permeated by a colour or scent",
#                     "to be infected, to be contagious, to spread (as in fire)"
#                 ]
#             },
#             {
#                 "kanji_full": "\u8155",
#                 "hiragana_full": "\u3046\u3067",
#                 "id": "736",
#                 "edict_ent": "1562850",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 25,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "25",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/08/18",
#                             "next_quiz": "2024/10/27"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 12,
#                             "missed_count": 0,
#                             "mastery_perc": 63,
#                             "last_quizzed": "2024/08/17",
#                             "next_quiz": "2024/10/13"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/19"
#                         }
#                     }
#                 },
#                 "reibuns": "142",
#                 "pitch": [
#                     "\u3046\u2b67\u3067\u2b68"
#                 ],
#                 "typeofspeech": "(noun)",
#                 "def": [
#                     "arm",
#                     "skill, efforts, ability"
#                 ]
#             },
#             {
#                 "kanji_full": "\u88cf",
#                 "hiragana_full": "\u3046\u3089",
#                 "id": "738",
#                 "edict_ent": "1550190",
#                 "config": [
#                     "ent_single"
#                 ],
#                 "user_data": {
#                     "correct_count": 29,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "20",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 16,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/08/15",
#                             "next_quiz": "2024/09/18"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 13,
#                             "missed_count": 0,
#                             "mastery_perc": 50,
#                             "last_quizzed": "2024/08/06",
#                             "next_quiz": "2024/09/09"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/16"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/16"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/16"
#                         }
#                     }
#                 },
#                 "reibuns": "27",
#                 "pitch": [
#                     "\u3046\u2b67\u3089\u2b68"
#                 ],
#                 "typeofspeech": "(noun)",
#                 "def": [
#                     "opposite side, bottom, other side, side hidden from view, undersurface, reverse side",
#                     "rear, back, behind",
#                     "lining, inside",
#                     "in the shadows, behind the scenes, offstage, behind (someone's) back",
#                     "more (to something than meets the eye), hidden side (e.g. of one's personality), unknown circumstances, different side",
#                     "proof",
#                     "opposite (of a prediction, common sense, etc.), contrary",
#                     "inverse (of a hypothesis, etc.)",
#                     "{baseb} bottom (of an inning), last half (of an inning)"
#                 ]
#             },
#             {
#                 "kanji_full": "",
#                 "hiragana_full": "\u3046\u3093",
#                 "id": "742",
#                 "edict_ent": "1001090",
#                 "config": [
#                     "ent_primary"
#                 ],
#                 "user_data": {
#                     "correct_count": 3,
#                     "missed_count": 0,
#                     "mastery_avg_perc": "8",
#                     "study_vectors": {
#                         "Kanji > Kana": {
#                             "name": "Kanji > Kana",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Kanji": {
#                             "name": "Kana > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kanji > Meaning": {
#                             "name": "Kanji > Meaning",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Meaning > Kanji": {
#                             "name": "Meaning > Kanji",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "Now"
#                         },
#                         "Kana > Meaning": {
#                             "name": "Kana > Meaning",
#                             "correct_count": 1,
#                             "missed_count": 0,
#                             "mastery_perc": 13,
#                             "last_quizzed": "2024/08/27",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Meaning > Kana": {
#                             "name": "Meaning > Kana",
#                             "correct_count": 2,
#                             "missed_count": 0,
#                             "mastery_perc": 25,
#                             "last_quizzed": "2024/08/22",
#                             "next_quiz": "2024/09/01"
#                         },
#                         "Listening": {
#                             "name": "Listening",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Accent": {
#                             "name": "Accent",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         },
#                         "Writing": {
#                             "name": "Writing",
#                             "correct_count": 0,
#                             "missed_count": 0,
#                             "mastery_perc": 0,
#                             "last_quizzed": "Not yet",
#                             "next_quiz": "2024/08/28"
#                         }
#                     }
#                 },
#                 "reibuns": "37",
#                 "pitch": [
#                     "\u2b67\u3046\u2b68\u3093"
#                 ],
#                 "typeofspeech": "(expression)",
#                 "def": [
#                     "yes, yeah, uh huh",
#                     "hum, hmmm, well, erm, huh?",
#                     "oof (moan or groan (of pain))"
#                 ]
#             }
#         ]
#     },
#     "api_usage": {
#         "calls_today": 9,
#         "daily_allowance": 2000
#     }
# }
