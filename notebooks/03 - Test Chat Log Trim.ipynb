# %%
from textwrap import dedent
from warui_genai.utils.chat_log import trim_chat_log
from warui_genai.models.chat import (
    HumanMessage,
    AIMessage,
)

# %%
# NOTE: Claude 3 Sonnet seems to get this wrong sometimes
    # it responds to the conversation instead of summarizing

chat_log = [
    HumanMessage(dedent('''
        ゲームは好きですか？
    ''').strip()),
    AIMessage(dedent('''
        ゲームは好きです！いろいろなジャンルのゲームを楽しむことができます。あなたはどんなゲームが好きですか？
    ''').strip()),
    HumanMessage(dedent('''
        最近ファイナルファンタジー7 リバースをたくさんしていた
    ''').strip()),
    AIMessage(dedent('''
        それは素晴らしいですね！ファイナルファンタジー7 リバースは、ファイナルファンタジー7のリメイク作品の続編として多くのファンから期待されています。ゲームのどの部分が特に気に入っていますか？
    ''').strip()),
    HumanMessage(dedent('''
        このゲームの世界はとても美しいだよ！見たことある？
    ''').strip()),
    AIMessage(dedent('''
        ファイナルファンタジー7 リバースの美しい世界は、たくさんのプレイヤーにとって大きな魅力の一つですね。特に最新のグラフィックス技術を駆使して、細部まで丁寧に描かれているところが素晴らしいです。実際にプレイしたことはないですが、映像やスクリーンショットを見てその美しさに感動しました。お気に入りの場所やシーンはありますか？
    ''').strip()),
    HumanMessage(dedent('''
        その質問は難しい！ぜんぶんの場所は好きだけど、カルムの町は一番好きだと思う
    ''').strip()),
    AIMessage(dedent('''
        カルムの町はとても魅力的な場所ですね！静かで平和な雰囲気があり、特にストーリーの進行において重要なシーンもあります。町のデザインや音楽も素晴らしいと思います。他にもお気に入りのキャラクターやエピソードがありますか？
    ''').strip()),
    HumanMessage(dedent('''
        はいはい！たくさんキャラクターは好きだ。おすすめの同じようなゲームがある？
    ''').strip()),
    AIMessage(dedent('''
        ファイナルファンタジー7 リバースのようなゲームが好きなら、以下のゲームも楽しめるかもしれません：

        1. **ファイナルファンタジー XV** - 広大なオープンワールドと美しいグラフィックが特徴です。友情や冒険をテーマにしたストーリーも魅力です。

        2. **キングダム ハーツ III** - ファイナルファンタジーのキャラクターとディズニーの世界が融合したアクションRPG。豊富なストーリーと美しいグラフィックが楽しめます。

        3. **ニーア オートマタ** - 美しい世界観と深いストーリー、アクション性の高い戦闘が特徴のRPG。哲学的なテーマも魅力です。

        4. **ペルソナ5** - スタイリッシュなビジュアルと緻密なストーリー、ターン制の戦闘システムが特徴です。高校生としての生活とダンジョン探索が交互に楽しめます。

        5. **ドラゴンクエスト XI** - クラシックなRPGの要素を持ちながらも、現代的なグラフィックとストーリーテリングが魅力の作品です。

        どのゲームも独自の魅力がありますので、気になるものがあればぜひ試してみてください！
    ''').strip()),
    HumanMessage(dedent('''
        ペルソナ５の物語は分かりやすいですか？
    ''').strip()),
    AIMessage(dedent('''
        ペルソナ5の物語は基本的にわかりやすいですが、非常に深みがあり、複雑なテーマやキャラクターのバックストーリーが含まれています。ゲームの進行とともに、プレイヤーは高校生としての生活や「心の怪盗団」としての活動を通じて、社会の不正や腐敗と戦うことになります。

        以下は、ペルソナ5の物語の主な特徴です：

        1. **シンプルな基本ストーリー** - 主人公は転校生として新しい学校に通い始め、仲間たちと共に「心の怪盗団」として活動し、人々の心を変えることで社会の問題を解決していきます。

        2. **キャラクターのバックストーリー** - 各キャラクターにはそれぞれ深いバックストーリーがあり、彼らの過去や成長が物語の進行とともに明らかになります。

        3. **テーマの深さ** - ゲームは権力の乱用、社会の不正、個人の自由など、現代社会の問題をテーマにしています。これらのテーマが物語に深みを加えています。

        4. **ダンジョン探索と日常生活** - プレイヤーはダンジョンを探索し、敵と戦う一方で、学校生活や友情、恋愛といった日常生活も楽しむことができます。このバランスが物語を豊かにしています。

        全体として、ペルソナ5の物語は理解しやすいものの、プレイヤーが深く掘り下げることでさらに多くの魅力を発見できるようになっています。ストーリーの進行に合わせて自然に理解できる構造になっているので、楽しみながら物語を追っていけるでしょう。
    ''').strip()),
    HumanMessage(dedent('''
        ああそのゲームの世界は同じ広いですか？
    ''').strip()),
    AIMessage(dedent('''
        ペルソナ5の世界は非常に広く、詳細に描かれていますが、ファイナルファンタジー7 リバースのようなオープンワールドとは異なります。以下にその違いと特徴を説明します：

        ### ペルソナ5の世界

        1. **都市と学校**:
        - 主に東京を舞台にしており、現実の都市のように細かく再現されたエリアがいくつかあります。
        - 主人公の通う高校やその周辺の街並み、地下鉄、ショッピングエリアなどが探索可能です。

        2. **パレス（ダンジョン）**:
        - 「心の怪盗団」としてターゲットの「パレス」に侵入し、敵と戦います。パレスはそれぞれユニークなデザインとテーマを持ち、攻略の仕方も異なります。
        - 一部のパレスは非常に広く、複雑な構造をしています。

        3. **日常生活のシミュレーション**:
        - 主人公は学校に通い、アルバイトをし、友人や仲間との関係を築いていきます。これらの日常生活の活動もゲームの重要な要素です。
        - 各エリアで行えるアクティビティが多く、カレンダーシステムにより、日々の計画を立てて進行します。

        ### ファイナルファンタジー7 リバースの世界

        1. **広大なオープンワールド**:
        - 広大でシームレスなオープンワールドを探索でき、様々な地域や都市、自然環境があります。
        - エリア間の移動も自由で、多くのサイドクエストや隠し要素が存在します。

        2. **リアルタイムアクションとストーリー進行**:
        - 戦闘はリアルタイムで行われ、キャラクターのスキルや魔法を駆使して戦います。
        - メインストーリーとサイドストーリーが豊富で、物語の進行に合わせて広がる世界を楽しむことができます。

        ### 比較

        - **ペルソナ5**は、よりストーリー主導型で、日常生活とダンジョン探索のバランスが特徴です。エリアは細かく作り込まれていますが、オープンワールドのような広がりはありません。
        - **ファイナルファンタジー7 リバース**は、広大なオープンワールドを自由に探索できる点で異なり、リアルタイムで進行する戦闘や広がりのある世界が特徴です。

        どちらのゲームも独自の魅力がありますが、プレイスタイルや好みによって選ぶと良いでしょう。
    ''').strip()),
    HumanMessage(dedent('''
        ペルソナ５のセールはいつかをしていますか？
    ''').strip()),
    AIMessage(dedent('''
        Yes, *Persona 5 Royal* is currently on sale in Japan at a 50% discount on the Nintendo eShop until January 10, 2024. The sale will also be available on the PlayStation Store and Steam in the coming days【26†source】【27†source】. Keep an eye out for these platforms to grab the game at a discounted price!

        Enjoy exploring the world of *Persona 5*—it's known for its deep story and stylish gameplay.
    ''').strip()),
    HumanMessage(dedent('''
        これ日本語で教えてください
    ''').strip()),
    AIMessage(dedent('''
        はい、*ペルソナ5 ロイヤル*は現在、日本のニンテンドーeショップで50%オフのセール中です。このセールは2024年1月10日まで続きます。さらに、今後数日以内にPlayStation StoreやSteamでもセールが予定されています【27†source】。

        この機会に、スタイリッシュなゲームプレイと深いストーリーを楽しんでくださいね！
    ''').strip()),
]

print(len(chat_log))
trimmed_log = trim_chat_log(
    chat_log,
    threshold = 8,
    trim_to = 4
)
print(len(trimmed_log))
print(*trimmed_log, sep = "\n")
# Out:
# 18
# 4
# Running Summary: この会話では、ゲームについて話し合っています。人間はファイナルファンタジー7 リバースを楽しんでおり、その美しい世界観を称賛しています。AIはペルソナ5を含む類似のゲームを推薦し、その物語の複雑さと世界観について説明しました。最後に、人間はペルソナ5のセールについて尋ねています。
# ai: Yes, *Persona 5 Royal* is currently on sale in Japan at a 50% discount on the Nintendo eShop until January 10, 2024. The sale will also be available on the PlayStation Store and Steam in the coming days【26†source】【27†source】. Keep an eye out for these platforms to grab the game at a discounted price!
#
# Enjoy exploring the world of *Persona 5*—it's known for its deep story and stylish gameplay.
# human: これ日本語で教えてください
# ai: はい、*ペルソナ5 ロイヤル*は現在、日本のニンテンドーeショップで50%オフのセール中です。このセールは2024年1月10日まで続きます。さらに、今後数日以内にPlayStation StoreやSteamでもセールが予定されています【27†source】。
#
# この機会に、スタイリッシュなゲームプレイと深いストーリーを楽しんでくださいね！
