# %%
import os
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from warui_genai.renshuu import get_focus_terms_from_schedules

# %%
focus_terms = get_focus_terms_from_schedules(
    levels = ["n4"]
)
# Out:
# [
#     {
#         "id": "4419328",
#         "name": "Pre-Intermediate Words (N4)",
#         "is_frozen": 0,
#         "today": {
#             "review": 163,
#             "new": 20
#         },
#         "upcoming": [
#             {
#                 "days_in_future": "1",
#                 "terms_to_review": "17"
#             },
#             {
#                 "days_in_future": "2",
#                 "terms_to_review": "17"
#             },
#             {
#                 "days_in_future": "3",
#                 "terms_to_review": "18"
#             },
#             {
#                 "days_in_future": "4",
#                 "terms_to_review": "19"
#             },
#             {
#                 "days_in_future": "5",
#                 "terms_to_review": "21"
#             },
#             {
#                 "days_in_future": "6",
#                 "terms_to_review": "5"
#             },
#             {
#                 "days_in_future": "7",
# ...
